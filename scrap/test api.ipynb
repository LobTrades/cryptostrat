# %%
1+1
# Out:
# 2

# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

# %%
cg.get_price(ids='bitcoin', vs_currencies='usd')
# Out:
# {'bitcoin': {'usd': 40959}}

# %%
cg.get_price(ids=['bitcoin', 'litecoin', 'ethereum'], vs_currencies='usd')
# Out:
# {'bitcoin': {'usd': 41047},
#  'ethereum': {'usd': 2139.97},
#  'litecoin': {'usd': 68.71}}

# %%
cg.get_price(ids=['bitcoin', 'litecoin', 'ethereum'], vs_currencies=['usd', 'eur'])
# Out:
# {'bitcoin': {'usd': 41047, 'eur': 37597},
#  'ethereum': {'usd': 2139.97, 'eur': 1960.1},
#  'litecoin': {'usd': 68.71, 'eur': 62.93}}

# %%
cg.get_price(ids='bitcoin', vs_currencies='usd', include_market_cap='true', include_24hr_vol='true', include_24hr_change='true', include_last_updated_at='true')
# Out:
# {'bitcoin': {'usd': 41043,
#   'usd_market_cap': 803362331315.4152,
#   'usd_24h_vol': 19088229561.787853,
#   'usd_24h_change': -2.028791422694397,
#   'last_updated_at': 1702902801}}

# %%
cg.get_price(ids='bitcoin', vs_currencies='usd', include_market_cap=True, include_24hr_vol=True, include_24hr_change=True, include_last_updated_at=True)
# Out:
# {'bitcoin': {'usd': 41043,
#   'usd_market_cap': 803362331315.4152,
#   'usd_24h_vol': 19088229561.787853,
#   'usd_24h_change': -2.028791422694397,
#   'last_updated_at': 1702902801}}

# %%
cg.get_coins_list()
# Out:
# [{'id': '01coin', 'symbol': 'zoc', 'name': '01coin'},
#  {'id': '0chain', 'symbol': 'zcn', 'name': 'Zus'},
#  {'id': '0-knowledge-network', 'symbol': '0kn', 'name': '0 Knowledge Network'},
#  {'id': '0-mee', 'symbol': 'ome', 'name': 'O-MEE'},
#  {'id': '0vix-protocol', 'symbol': 'vix', 'name': '0VIX Protocol'},
#  {'id': '0x', 'symbol': 'zrx', 'name': '0x Protocol'},
#  {'id': '0x0-ai-ai-smart-contract',
#   'symbol': '0x0',
#   'name': '0x0.ai: AI Smart Contract'},
#  {'id': '0x1-tools-ai-multi-tool',
#   'symbol': '0x1',
#   'name': '0x1.tools: AI Multi-tool'},
#  {'id': '0xaiswap', 'symbol': '0xaiswap', 'name': '0xAISwap'},
#  {'id': '0xanon', 'symbol': '0xanon', 'name': '0xAnon'},
#  {'id': '0xblack', 'symbol': '0xb', 'name': '0xBlack'},
#  {'id': '0xcoco', 'symbol': 'coco', 'name': '0xCoco'},
#  {'id': '0xconnect', 'symbol': '0xcon', 'name': '0xConnect'},
#  {'id': '0xdao', 'symbol': 'oxd', 'name': '0xDAO'},
#  {'id': '0xdefcafe', 'symbol': 'cafe', 'name': '0xDEFCAFE'},
# ...

# %%
cg.get_search_trending()
# Out:
# {'coins': [{'item': {'id': 'bonk',
#     'coin_id': 28600,
#     'name': 'Bonk',
#     'symbol': 'BONK',
#     'market_cap_rank': 57,
#     'thumb': 'https://assets.coingecko.com/coins/images/28600/thumb/bonk.jpg?1696527587',
#     'small': 'https://assets.coingecko.com/coins/images/28600/small/bonk.jpg?1696527587',
#     'large': 'https://assets.coingecko.com/coins/images/28600/large/bonk.jpg?1696527587',
#     'slug': 'bonk',
#     'price_btc': 4.6342401821503756e-10,
#     'score': 0,
#     'data': {'price': '$0.000018976822',
#      'price_btc': '0.000000000463424018215038',
#      'price_change_percentage_24h': {'aed': -9.683128295484583,
#       'ars': -8.570352714857211,
#       'aud': -10.078785370277291,
#       'bch': -7.058395405516612,
#       'bdt': -10.375775969145769,
#       'bhd': -10.185238024491463,
#       'bmd': -9.68005426460348,
#       'bnb': -7.076079199508893,
#       'brl': -9.635703577562635,
#       'btc': -7.60950400200864,
# ...

# %%
cg.get_coin_history_by_id('babydoge2-0')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cg.get_coin_history_by_id('babydoge2-0')
#
# File ~\anaconda3\envs\cryptostrat\lib\site-packages\pycoingecko\utils.py:12, in func_args_preprocessing.<locals>.input_args(*args, **kwargs)
#       9 # check in *args for lists and booleans
#      10 args = [arg_preprocessing(v) for v in args]
# ---> 12 return func(*args, **kwargs)
#
# TypeError: CoinGeckoAPI.get_coin_history_by_id() missing 1 required positional argument: 'date'

# %%
cg.get_coin_history_by_id('bitcoin','2023-12-10')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\cryptostrat\lib\site-packages\pycoingecko\api.py:34, in CoinGeckoAPI.__request(self, url)
#      33 try:
# ---> 34     response.raise_for_status()
#      35     content = json.loads(response.content.decode('utf-8'))
#
# File ~\anaconda3\envs\cryptostrat\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.coingecko.com/api/v3/coins/bitcoin/history?date=2023-12-10
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cg.get_coin_history_by_id('bitcoin','2023-12-10')
#
# ...

# %%
cg.get_coin_history_by_id('bitcoin','2023-01-01')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\cryptostrat\lib\site-packages\pycoingecko\api.py:34, in CoinGeckoAPI.__request(self, url)
#      33 try:
# ---> 34     response.raise_for_status()
#      35     content = json.loads(response.content.decode('utf-8'))
#
# File ~\anaconda3\envs\cryptostrat\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.coingecko.com/api/v3/coins/bitcoin/history?date=2023-01-01
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 cg.get_coin_history_by_id('bitcoin','2023-01-01')
#
# ...

# %%
cg.get_coin_history_by_id('bitcoin','01-01-2023')
# Out:
# {'id': 'bitcoin',
#  'symbol': 'btc',
#  'name': 'Bitcoin',
#  'localization': {'en': 'Bitcoin',
#   'de': 'Bitcoin',
#   'es': 'Bitcoin',
#   'fr': 'Bitcoin',
#   'it': 'Bitcoin',
#   'pl': 'Bitcoin',
#   'ro': 'Bitcoin',
#   'hu': 'Bitcoin',
#   'nl': 'Bitcoin',
#   'pt': 'Bitcoin',
#   'sv': 'Bitcoin',
#   'vi': 'Bitcoin',
#   'tr': 'Bitcoin',
#   'ru': 'Биткоин',
#   'ja': 'ビットコイン',
#   'zh': '比特币',
#   'zh-tw': '比特幣',
#   'ko': '비트코인',
#   'ar': 'بيتكوين',
#   'th': 'บิตคอยน์',
#   'id': 'Bitcoin',
#   'cs': 'Bitcoin',
#   'da': 'Bitcoin',
#   'el': 'Bitcoin',
#   'hi': 'Bitcoin',
#   'no': 'Bitcoin',
#   'sk': 'Bitcoin',
#   'uk': 'Bitcoin',
#   'he': 'Bitcoin',
#   'fi': 'Bitcoin',
#   'bg': 'Bitcoin',
#   'hr': 'Bitcoin',
#   'lt': 'Bitcoin',
#   'sl': 'Bitcoin'},
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/1/thumb/bitcoin.png?1696501400',
#   'small': 'https://assets.coingecko.com/coins/images/1/small/bitcoin.png?1696501400'},
# ...

# %%
cg.get_coin_history_by_id('eth','01-01-2023')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\cryptostrat\lib\site-packages\pycoingecko\api.py:34, in CoinGeckoAPI.__request(self, url)
#      33 try:
# ---> 34     response.raise_for_status()
#      35     content = json.loads(response.content.decode('utf-8'))
#
# File ~\anaconda3\envs\cryptostrat\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://api.coingecko.com/api/v3/coins/eth/history?date=01-01-2023
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 cg.get_coin_history_by_id('eth','01-01-2023')
#
# ...

# %%
# Out:
# {'id': 'ethereum',
#  'symbol': 'eth',
#  'name': 'Ethereum',
#  'localization': {'en': 'Ethereum',
#   'de': 'Ethereum',
#   'es': 'Ethereum',
#   'fr': 'Ethereum',
#   'it': 'Ethereum',
#   'pl': 'Ethereum',
#   'ro': 'Ethereum',
#   'hu': 'Ethereum',
#   'nl': 'Ethereum',
#   'pt': 'Ethereum',
#   'sv': 'Ethereum',
#   'vi': 'Ethereum',
#   'tr': 'Ethereum',
#   'ru': 'Эфириум',
#   'ja': 'イーサリアム',
#   'zh': '以太坊',
#   'zh-tw': '以太幣',
#   'ko': '이더리움',
#   'ar': 'يثريوم',
#   'th': 'Ethereum',
#   'id': 'Ethereum',
#   'cs': 'Ethereum',
#   'da': 'Ethereum',
#   'el': 'Ethereum',
#   'hi': 'Ethereum',
#   'no': 'Ethereum',
#   'sk': 'Ethereum',
#   'uk': 'Ethereum',
#   'he': 'Ethereum',
#   'fi': 'Ethereum',
#   'bg': 'Ethereum',
#   'hr': 'Ethereum',
#   'lt': 'Ethereum',
#   'sl': 'Ethereum'},
#  'image': {'thumb': 'https://assets.coingecko.com/coins/images/279/thumb/ethereum.png?1696501628',
# ...

# %%
cg.get_coin_history_by_id(ids='ethereum', vs_currencies='usd', days=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 cg.get_coin_history_by_id(ids='ethereum', vs_currencies='usd', days=30)
#
# File ~\anaconda3\envs\cryptostrat\lib\site-packages\pycoingecko\utils.py:12, in func_args_preprocessing.<locals>.input_args(*args, **kwargs)
#       9 # check in *args for lists and booleans
#      10 args = [arg_preprocessing(v) for v in args]
# ---> 12 return func(*args, **kwargs)
#
# TypeError: CoinGeckoAPI.get_coin_history_by_id() missing 2 required positional arguments: 'id' and 'date'
